# %%
 from google.colab import drive 
drive.mount('/content/drive')
# !pip install PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
file_list = drive.ListFile(
    {'q': "'1ZQeS3F0HBwiEY0c3MLlMpnn7l_raK_6d' in parents"}).GetList()
from google.colab import auth
from oauth2client.client import GoogleCredentials
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.python.keras.optimizers import SGD
from tensorflow.python.keras.preprocessing.image import img_to_array
from tensorflow.python.keras.regularizers import l2
from tensorflow.python.keras.regularizers import l1
from tensorflow.python.keras import regularizers
from tensorflow.python.keras.layers import Dropout

from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os
import tensorflow as tf

from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers.convolutional import Conv2D
from tensorflow.python.keras.layers.core import Activation
from tensorflow.python.keras.layers.core import Flatten
from tensorflow.python.keras.layers.core import Dense
from tensorflow.python.keras.layers.pooling import *
from keras import backend as K

print("Loading Images")
imagePaths = list(paths.list_images("/content/drive/My Drive/By_Contaminent_Select"))
print(imagePaths)
verbose=-1
data = []
labels = []

# loop over the input images
for (i, imagePath) in enumerate(imagePaths):
  image = cv2.imread(imagePath)
  label = imagePath.split(os.path.sep)[-2]
  image=cv2.resize(image, (32, 32),
  interpolation=cv2.INTER_AREA)
  image=img_to_array(image, None)
  data.append(image)
  labels.append(label)
  print("[INFO] processed {}/{}, {}".format(i + 1, len(imagePaths), label))

data= np.array(data)
labels = np.array(labels)
data = data.astype("float")/255.0
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.25, random_state=42)
trainY = LabelBinarizer().fit_transform(trainY)
testY = LabelBinarizer().fit_transform(testY)

print("Compiling Model")
opt = tf.keras.optimizers.SGD(lr=0.005)
model = Sequential()
inputShape = (32, 32, 3)

if K.image_data_format() == "channels_first":
  inputShape = (3, 32, 32)

model.add(Conv2D(32, (3, 3), padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Activation("relu"))
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(6, input_dim=64, kernel_regularizer=regularizers.l2(0.01), activity_regularizer=regularizers.l1(0.01)))
model.add(Activation("softmax"))

model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

print("Training network")
H = model.fit(trainX, trainY, validation_data=(testX, testY), batch_size=50, epochs=100, verbose=-1)
print("Evaluating network")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=["Clean", "Salt", "Soil", "Sand", "Algae", "Plastic"]))

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0,100), H.history["loss"], label="train_loss")
plt.plot(np.arange(0,100), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0,100), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0,100), H.history["val_accuracy"], label="val_acc")
plt.title("Training loss and accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.7.12)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.0.3)
# Requirement already satisfied: httplib2<1dev,>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.17.3)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.7.2)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.1)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.12.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (46.3.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->PyDrive) (3.1.1)
# Using TensorFlow backend.
# Loading Images
# ['/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_1.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_11.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_10.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_12.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_13.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_14.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_21.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_15.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_16.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_20.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_19.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_2.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_17.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_18.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_22.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_23.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_29.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_27.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_24.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_26.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_25.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_28.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_3.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_31.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_30.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_32.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_4.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Top_Image_10.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Top_Image_11.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Top_Image_1.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_7.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_8.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_5.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_6.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Image_9.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Top_Image_12.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Top_Image_16.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Top_Image_2.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Top_Image_18.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Top_Image_13.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Top_Image_20.jpg', '/content/drive/My Drive/By_Contaminent_Select/Plastic/NIR_Tap_Water_Plastic_1_Top_Image_14.jpg', '/content/drive/My Dri ...
# [INFO] processed 1/5019, Plastic
# [INFO] processed 2/5019, Plastic
# [INFO] processed 3/5019, Plastic
# [INFO] processed 4/5019, Plastic
# [INFO] processed 5/5019, Plastic
# [INFO] processed 6/5019, Plastic
# [INFO] processed 7/5019, Plastic
# [INFO] processed 8/5019, Plastic
